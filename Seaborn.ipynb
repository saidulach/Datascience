# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psutil

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_theme()

# %%
sns.relplot(data = df, x="total_bill", y = "tip", col="time", hue="smoker", style="smoker", size="total_bill")

# %%
sns.histplot(df['total_bill'], kernel='kde')

# %%
print(psutil.virtual_memory())
# Out:
# svmem(total=33585426432, available=11839541248, percent=64.7, used=21745885184, free=11839541248)
